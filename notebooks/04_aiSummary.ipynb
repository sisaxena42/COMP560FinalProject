# %%
import os, sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /workspaces/COMP560FinalProject

# %%
import os
from dotenv import load_dotenv
load_dotenv()

print("Anthropic Key visible?", "ANTHROPIC_API_KEY" in os.environ)
print("Key length:", len(os.getenv("ANTHROPIC_API_KEY", "")))
# Out:
# Anthropic Key visible? True
# Key length: 108

# %%
from AI.summarizer import summarize_results

summary_data = {
    "n_rows": 150,
    "regression_results": {
        "linear": {"r2": 0.72, "rmse": 1840.3},
        "sgd": {"r2": 0.69, "rmse": 1922.5},
    },
    "classification_results": {
        "logreg_gd": {"accuracy": 0.81, "f1": 0.79},
    },
    "top_features": [
        {"name": "Air pollution", "coef": -0.41},
        {"name": "Child wasting", "coef": -0.32},
    ]
}

summary = summarize_results(summary_data)
print(summary)
# Out:
# The machine learning models used in this project demonstrated promising results in predicting country-level GDP from environmental and clinical risk factors. The linear regression model performed well, with a strong coefficient of determination (R-squared) and relatively low root mean squared error (RMSE), indicating the model can accurately estimate GDP based on the input features. The stochastic gradient descent (SGD) regression model also performed reasonably well, though slightly less than the linear model.
#
# The classification model, using logistic regression with gradient descent, achieved high accuracy and F1-score, suggesting it can effectively categorize countries into different GDP levels based on the provided risk factors.
#
# The feature importance analysis revealed that two variables, "Air pollution" and "Child wasting," were the most predictive of GDP. Interestingly, both features exhibited negative coefficients, indicating that higher levels of air pollution and child wasting are associated with lower GDP.
#
# Overall, the results of this project suggest that environmental and clinical risk factors can be valuable predictors of country-level economic performance. The models demonstrate a good balance of predictive power and interpretability, highlighting the potential of using these types of features for GDP forecasting and economic policy planning at the national level.
